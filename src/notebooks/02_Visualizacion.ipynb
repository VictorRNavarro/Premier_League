# %% [markdown]
# # Visualizaciones

# %%
import pandas as pd
from visualizacion.visualizador import Visualizador

df_clean = pd.read_csv("../data/processed/premier_clean.csv", parse_dates=["Date"])

visual = Visualizador(df_clean)

# %%
visual.distribucion_edad()

# %%
visual.top_goleadores()

# %%
visual.top_asistencias()

# %%
visual.distribucion_minutos()

# %%
visual.xg_vs_goles()

# %%
visual.frecuencia_posiciones()
